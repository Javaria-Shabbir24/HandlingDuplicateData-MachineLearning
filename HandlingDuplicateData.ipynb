# %%
import pandas as pd

# %%
data={"name": ["a","b","a","c","d","a"], "eng":[8,7,8,6,7,3], "urdu":[1,2,1,1,3,5]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   name  eng  urdu
# 0    a    8     1
# 1    b    7     2
# 2    a    8     1
# 3    c    6     1
# 4    d    7     3
# 5    a    3     5

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#   name  eng  urdu
# 0    a    8     1
# 1    b    7     2
# 3    c    6     1
# 4    d    7     3
# 5    a    3     5

# %%
dataset = pd.read_excel("D:\Study\Machine Learning\FeatureScaling\dataset1.xlsx")

# %%
dataset.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 485     True
# 486     True
# 487     True
# 488     True
# 489     True
# Length: 490, dtype: bool

# %%
dataset["duplicates"]=dataset.duplicated()

# %%
dataset
# Out:
#      type Urgency severity  priority  duplicates
# 0    Task     low    minor       4.0       False
# 1    Task     NaN    minor       4.0       False
# 2    Task     low    minor       NaN       False
# 3    Task     low      NaN       4.0       False
# 4    Task     NaN    minor       4.0        True
# ..    ...     ...      ...       ...         ...
# 485  Task     low    minor       4.0        True
# 486  Task     low    minor       4.0        True
# 487   Bug     low    minor       4.0        True
# 488   Bug     low    minor       4.0        True
# 489  Task     low    minor       4.0        True
#
# [490 rows x 5 columns]

# %%
dataset.drop_duplicates(inplace=True)
dataset["duplicates"]=dataset.duplicated()

# %%
dataset
# Out:
#            type Urgency severity  priority  duplicates
# 0          Task     low    minor       4.0       False
# 1          Task     NaN    minor       4.0       False
# 2          Task     low    minor       NaN       False
# 3          Task     low      NaN       4.0       False
# 4          Task     NaN    minor       4.0       False
# 5          Task     low    minor       4.0       False
# 7          Task     low    minor       NaN       False
# 11         Task     low      NaN       4.0       False
# 31         Task  medium    minor       4.0       False
# 49         Task  medium    minor       4.0       False
# 53          Bug     low    minor       4.0       False
# 54          Bug     low    minor       4.0       False
# 55          Bug  medium    minor       4.0       False
# 57          Bug    high    minor       4.0       False
# 65          Bug    high    minor       4.0       False
# 67          Bug     low    minor       1.0       False
# ...
